# %% [markdown]
# # K-Means on Spark Lab Runbook
#
# Portfolio companion to the original lab artifact. Original documents remain preserved.
#
# ## Journey
# Question, dataset review, cleaning, feature preparation, scaling, cluster selection, model execution, evaluation, interpretation, and modernization.
#
# ## Compatibility Lens
# Keep the historical exercise intact and annotate current status separately. Compare older Spark examples with current DataFrame-based Spark ML pipelines and supported evaluation tools.
#
# ## Evidence
# Place reviewed screenshots and plots beside the experiment step they demonstrate.
#
# ## Validation
# Check scaling assumptions, random seed handling, cluster-count selection, evaluation metrics, stability, and interpretation limits.
#
# ## Future State
# Add the source sequence, screenshots, sample data, expected results, and a current Spark ML equivalent.
